# %% [markdown]
# <a href="https://colab.research.google.com/github/anujmore15/Youtube-Scraping---Analysis/blob/main/youtube_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
import pandas as pd
import plotly.express as px

# %%
api_key = 'AIzaSyC0zyFqXjPwEuICNBa67oJQL61KyMH9OuU'
#channel_id = 'UC_Q-YjEXDN0ufkU4AoWhU1g'
channel_ids = ['UC0WP5P-ufpRfjbNrmOWwLBQ',
               'UCByOQJjav0CUDwxCk-jVNRQ',
               'UCnc6db-y3IU7CkT_yeVXdVg', 
               'UCtxdfwb9wfkoGocVUAJ-Bmg', 
               'UCeLHszkByNZtPKcaVXOCOQQ', 
               'UC0KAFLxIiaR_FFNYDL3utGw'] 

youtube = build('youtube', 'v3', developerKey = api_key)

# %% [markdown]
# ## Fuction to get channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
  all_data = []
  request = youtube.channels().list(
                part = "snippet,contentDetails,statistics", 
                id = ','.join(channel_ids))
  response = request.execute()

  for i in range(len(response['items'])):
    data = dict(channel_name = response['items'][i]['snippet']['title'], 
              subscribers = response['items'][i]['statistics']['subscriberCount'], 
              views = response['items'][i]['statistics']['viewCount'], 
              total_videos = response['items'][i]['statistics']['videoCount'],
              playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
              )
    all_data.append(data)
  return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_statistics
# Out:
# [{'channel_name': 'Post Malone',
#   'subscribers': '24300000',
#   'views': '12594045260',
#   'total_videos': '52',
#   'playlist_id': 'UUeLHszkByNZtPKcaVXOCOQQ'},
#  {'channel_name': 'The Weeknd',
#   'subscribers': '29300000',
#   'views': '19468654436',
#   'total_videos': '124',
#   'playlist_id': 'UU0WP5P-ufpRfjbNrmOWwLBQ'},
#  {'channel_name': 'Travis Scott',
#   'subscribers': '16100000',
#   'views': '7229966172',
#   'total_videos': '13',
#   'playlist_id': 'UUtxdfwb9wfkoGocVUAJ-Bmg'},
#  {'channel_name': 'ASAPROCKYUPTOWN',
#   'subscribers': '4750000',
#   'views': '2799643398',
#   'total_videos': '64',
#   'playlist_id': 'UU0KAFLxIiaR_FFNYDL3utGw'},
#  {'channel_name': 'J. Cole',
#   'subscribers': '6590000',
#   'views': '2726170093',
#   'total_videos': '76',
#   'playlist_id': 'UUnc6db-y3IU7CkT_yeVXdVg'},
#  {'channel_name': 'Drake',
#   'subscribers': '26900000',
#   'views': '13061272266',
#   'total_videos': '53',
#   'playlist_id': 'UUByOQJjav0CUDwxCk-jVNRQ'}]

# %%
df = pd.DataFrame(channel_statistics)

# %%
df
# Out:
#       channel_name subscribers        views total_videos  \
# 0      Post Malone    24300000  12594045260           52
# 1       The Weeknd    29300000  19468654436          124
# 2     Travis Scott    16100000   7229966172           13
# 3  ASAPROCKYUPTOWN     4750000   2799643398           64
# 4          J. Cole     6590000   2726170093           76
# 5            Drake    26900000  13061272266           53
#
#                 playlist_id
# 0  UUeLHszkByNZtPKcaVXOCOQQ
# 1  UU0WP5P-ufpRfjbNrmOWwLBQ
# 2  UUtxdfwb9wfkoGocVUAJ-Bmg
# 3  UU0KAFLxIiaR_FFNYDL3utGw
# 4  UUnc6db-y3IU7CkT_yeVXdVg
# 5  UUByOQJjav0CUDwxCk-jVNRQ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_name  6 non-null      object
#  1   subscribers   6 non-null      object
#  2   views         6 non-null      object
#  3   total_videos  6 non-null      object
#  4   playlist_id   6 non-null      object
# dtypes: object(5)
# memory usage: 368.0+ bytes

# %%
df['subscribers'] = df['subscribers'].astype(int)
df['views'] = df['views'].astype(int)
df['total_videos'] = df['total_videos'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_name  6 non-null      object
#  1   subscribers   6 non-null      int64
#  2   views         6 non-null      int64
#  3   total_videos  6 non-null      int64
#  4   playlist_id   6 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 368.0+ bytes

# %%
fig = px.bar(df, x='channel_name', y='subscribers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x='channel_name', y='views')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x='channel_name', y='total_videos')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##FUNCTION TO GET VIDEO IDs

# %%
df
# Out:
#       channel_name  subscribers        views  total_videos  \
# 0      Post Malone     24300000  12594045260            52
# 1       The Weeknd     29300000  19468654436           124
# 2     Travis Scott     16100000   7229966172            13
# 3  ASAPROCKYUPTOWN      4750000   2799643398            64
# 4          J. Cole      6590000   2726170093            76
# 5            Drake     26900000  13061272266            53
#
#                 playlist_id
# 0  UUeLHszkByNZtPKcaVXOCOQQ
# 1  UU0WP5P-ufpRfjbNrmOWwLBQ
# 2  UUtxdfwb9wfkoGocVUAJ-Bmg
# 3  UU0KAFLxIiaR_FFNYDL3utGw
# 4  UUnc6db-y3IU7CkT_yeVXdVg
# 5  UUByOQJjav0CUDwxCk-jVNRQ

# %%
playlist_id = df.loc[df['channel_name']=='J. Cole', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):

  request = youtube.playlistItems().list(
      part = 'contentDetails',
      playlistId = playlist_id
  )
  response = request.execute()

  video_ids = []

  for i in range(len(response['items'])):
    video_ids.append(response['items'][i]['contentDetails']['videoId'])

  next_page_token = response['nextPageToken']
  more_pages = True

  while  more_pages:
    if next_page_token is None:
      more_pages = False
    else:
      request = youtube.playlistItems().list(
      part = 'contentDetails',
      playlistId = playlist_id, 
      pageToken = next_page_token
  )
      response = request.execute()
      for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
      next_page_token = response.get('nextPageToken')


  return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['zIs0t-lYBn8',
#  'HIHo2uSgTdE',
#  'YHwUmMl1crE',
#  '79-eKiehLIw',
#  'BnK9oeBI9G4',
#  'w3333Fo6ufY',
#  '-8Q4i2XwGY8',
#  'ZLX-GY0dJgc',
#  'gK07p6RGbtg',
#  'j_ouj5asrE4',
#  'kPy6Kd6Mm_I',
#  'wLQ8u3xRZd8',
#  'xAnKFdI0uyk',
#  'EOmjIBTCHRk',
#  'I3ek1tkaOZE',
#  'g3mVwt0B6G4',
#  '135bv6GhD2M',
#  'XK60CAyxqfE',
#  '_h82Y-9GMJ8',
#  'HCURqfqL8sI',
#  'it-DvwBAkxw',
#  'BWSx7kCKNI4',
#  'W5hSdGt2M8w',
#  'RTubr1uofLU',
#  'L3Vo-KLTF4Y',
#  'A_gYtTdXnqY',
#  '0nIB6BduHyY',
#  'oVaBgcJwkI4',
#  'MxiSSSa5K2s',
#  'OZa3HyVLimQ',
#  'hzMzrRWJw5Q',
#  '8b2kA2EA310',
#  'e8CLsYzE5wk',
#  'RNlQU-7y9Fo',
#  'gsKjJRSmYio',
#  'ufynqs_COF4',
#  'vvEUSUVk2kI',
#  'Z0esfR2G5Qo',
#  'BJGExyf833g',
#  '_891z6x3bL0',
#  'kUYWjE-nPeo',
#  'fW_CEgDDBiA',
#  '8AYjV7MIWcA',
#  'w-RId--fBhM',
#  'sFZf7fzIsvU',
#  'z9yNGIBWkkQ',
#  'KFON2ClYZJA',
#  'f16Gl6O8CTI',
#  'uv_tU258uoo',
#  'UGAlU7WqROA',
#  'Hp4xV3KWckA',
#  '-W0-NZYihRU',
#  'Hg7sdfePBtg',
#  's3mvlqzkJF4',
#  'kJzqsYkpCb4',
# ...

# %% [markdown]
# ##FUNCTION TO GET VIDEO DETAILS

# %%
def get_video_details(youtube, video_ids):

  all_video_stats = []

  for i in range(0, len(video_ids), 50):
     request = youtube.videos().list(
          part = 'snippet, statistics', 
          id = ','.join(video_ids[i:i+50])
     )

     response = request.execute()

     for video in response['items']:
          video_stats = dict(title = video['snippet']['title'], 
                            published_date = video['snippet']['publishedAt'], 
                            views = video['statistics']['viewCount'],
                            likes = video['statistics']['likeCount'],
                            comments = video['statistics']['commentCount'], 
                            )
          all_video_stats.append(video_stats)

  return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_details
# Out:
# [{'title': 'The AUDACITY II',
#   'published_date': '2022-02-15T18:11:05Z',
#   'views': '1797691',
#   'likes': '132131',
#   'comments': '3349'},
#  {'title': 'Bas - The Jackie (ft. J. Cole & Lil Tjay) [Live From The Off-Season Tour]',
#   'published_date': '2021-12-01T01:20:50Z',
#   'views': '878021',
#   'likes': '38603',
#   'comments': '1545'},
#  {'title': "J. Cole - Heaven's EP (Official Music Video)",
#   'published_date': '2021-09-22T00:56:41Z',
#   'views': '21990983',
#   'likes': '698659',
#   'comments': '39138'},
#  {'title': "J. Cole - p u n c h i n ' . t h e . c l o c k (Official Music Video)",
#   'published_date': '2021-06-03T18:08:42Z',
#   'views': '4873037',
#   'likes': '202435',
#   'comments': '10785'},
#  {'title': 'J. Cole - a p p l y i n g . p r e s s u r e (Official Music Video)',
#   'published_date': '2021-05-25T17:00:10Z',
#   'views': '10690132',
#   'likes': '342906',
#   'comments': '16976'},
# ...

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                 title        published_date  \
# 0                                     The AUDACITY II  2022-02-15T18:11:05Z
# 1   Bas - The Jackie (ft. J. Cole & Lil Tjay) [Liv...  2021-12-01T01:20:50Z
# 2        J. Cole - Heaven's EP (Official Music Video)  2021-09-22T00:56:41Z
# 3   J. Cole - p u n c h i n ' . t h e . c l o c k ...  2021-06-03T18:08:42Z
# 4   J. Cole - a p p l y i n g . p r e s s u r e (O...  2021-05-25T17:00:10Z
# ..                                                ...                   ...
# 72                    J. Cole Takes Over Lollapalooza  2010-08-12T16:39:09Z
# 73                        J. Cole Secret Show @ 40/40  2010-06-21T17:10:50Z
# 74                  J. Cole - "Who Dat" Video Trailer  2010-06-16T18:59:56Z
# 75          J. Cole - "Who Dat" (Cover Image Version)  2010-05-11T21:42:28Z
# 76     JAY-Z x J. Cole: The BP3 Tour | Greensboro, NC  2010-03-09T03:02:15Z
#
#        views   likes comments
# ...

# %%
video_data['published_date'] = pd.to_datetime(video_data['published_date'])
video_data['views'] = pd.to_numeric(video_data['views'])
video_data['likes'] = pd.to_numeric(video_data['likes'])

# %%
video_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           77 non-null     object
#  1   published_date  77 non-null     datetime64[ns, UTC]
#  2   views           77 non-null     int64
#  3   likes           77 non-null     int64
#  4   comments        77 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(2)
# memory usage: 3.1+ KB

# %%
top10_videos = video_data.sort_values(by='views', ascending= False).head(10)

# %%
top10_videos
# Out:
#                                                 title  \
# 32            J. Cole - MIDDLE CHILD (Official Audio)
# 35                            J. Cole - Kevin's Heart
# 22          J. Cole – Work Out (Official Music Video)
# 11  J. Cole - m y . l i f e  feat. 21 Savage, Morr...
# 7   J. Cole - p r i d e . i s . t h e . d e v i l ...
# 5          J. Cole - a m a r i (Official Music Video)
# 2        J. Cole - Heaven's EP (Official Music Video)
# 27          J. Cole - The Climb Back (Official Audio)
# 15         J. Cole - 9 5 . s o u t h (Official Audio)
# 17       J. Cole - i n t e r l u d e (Official Audio)
#
#               published_date      views    likes comments
# 32 2019-01-24 02:00:00+00:00  130208857  1183318    54412
# 35 2018-04-24 15:56:34+00:00   58828889   865585    30933
# 22 2020-12-09 20:00:05+00:00   57681815   568686     9332
# 11 2021-05-14 04:00:17+00:00   30394437   495680    21046
# 7  2021-05-14 04:00:17+00:00   28062795   421527    11302
# ...

# %%
fig = px.histogram(top10_videos, x="title", y="views")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
video_data
# Out:
#                                                 title  \
# 0                                     The AUDACITY II
# 1   Bas - The Jackie (ft. J. Cole & Lil Tjay) [Liv...
# 2        J. Cole - Heaven's EP (Official Music Video)
# 3   J. Cole - p u n c h i n ' . t h e . c l o c k ...
# 4   J. Cole - a p p l y i n g . p r e s s u r e (O...
# ..                                                ...
# 72                    J. Cole Takes Over Lollapalooza
# 73                        J. Cole Secret Show @ 40/40
# 74                  J. Cole - "Who Dat" Video Trailer
# 75          J. Cole - "Who Dat" (Cover Image Version)
# 76     JAY-Z x J. Cole: The BP3 Tour | Greensboro, NC
#
#               published_date     views   likes comments
# 0  2022-02-15 18:11:05+00:00   1797691  132131     3349
# 1  2021-12-01 01:20:50+00:00    878021   38603     1545
# 2  2021-09-22 00:56:41+00:00  21990983  698659    39138
# 3  2021-06-03 18:08:42+00:00   4873037  202435    10785
# ...

# %%
video_data.to_csv('J._cole_youtube_stats')
